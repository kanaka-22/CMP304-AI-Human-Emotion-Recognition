# %% [markdown]
# <a href="https://colab.research.google.com/github/kanaka-22/CMP304-AI-Human-Emotion-Recognition/blob/master/CT_SCAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import RMSprop
from keras.models import Sequential
from keras.layers import Conv2D,Conv3D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.preprocessing import image
from glob import glob

# %%
IMAGE_SIZE = [224, 224] 

# training config:
epochs = 100
batch_size = 32

# %%
covid_ct='/content/drive/My Drive/SARS-COVID-19 CT SCANS/COVID-CT'
non_covid_ct='/content/drive/My Drive/SARS-COVID-19 CT SCANS/non-COVID-CT'

# %%
covid_files = glob(covid_ct + '/*')
non_covid_ct_files = glob(non_covid_ct + '/*')

# %%
print("First 5 Covid Files: ",covid_files[0:5])
print("Total Count: ",len(covid_files))
print("First 5 NonCovid Files: ",non_covid_ct_files[0:5])
print("Total Count: ",len(non_covid_ct_files))
# Out:
# First 5 Covid Files:  ['/content/drive/My Drive/SARS-COVID-19 CT SCANS/COVID-CT/Covid (585).png', '/content/drive/My Drive/SARS-COVID-19 CT SCANS/COVID-CT/Covid (582).png', '/content/drive/My Drive/SARS-COVID-19 CT SCANS/COVID-CT/Covid (581).png', '/content/drive/My Drive/SARS-COVID-19 CT SCANS/COVID-CT/Covid (590).png', '/content/drive/My Drive/SARS-COVID-19 CT SCANS/COVID-CT/Covid (593).png']
# Total Count:  1252
# First 5 NonCovid Files:  ['/content/drive/My Drive/SARS-COVID-19 CT SCANS/non-COVID-CT/Non-Covid (586).png', '/content/drive/My Drive/SARS-COVID-19 CT SCANS/non-COVID-CT/Non-Covid (589).png', '/content/drive/My Drive/SARS-COVID-19 CT SCANS/non-COVID-CT/Non-Covid (582).png', '/content/drive/My Drive/SARS-COVID-19 CT SCANS/non-COVID-CT/Non-Covid (584).png', '/content/drive/My Drive/SARS-COVID-19 CT SCANS/non-COVID-CT/Non-Covid (583).png']
# Total Count:  1267

# %%
covid_ct_labels = []
non_covid_ct_labels = []

# %%
covid_ct_images=[]
non_covid_ct_images=[]

# %%
for i in range(len(covid_files)):
  import cv2 
  image = cv2.imread(covid_files[i])
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  image = cv2.resize(image,(224,224))
  covid_ct_images.append(image)
  covid_ct_labels.append('COVID_CT')

# %%
for i in range(len(non_covid_ct_files)):
  image = cv2.imread(non_covid_ct_files[i])
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  image = cv2.resize(image,(224,224))
  non_covid_ct_images.append(image)
  non_covid_ct_labels.append('NonCOVID_CT')

# %%
def plot_images(images, title):
    nrows, ncols = 5, 8
    figsize = [10, 6]
    fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=figsize, facecolor=(1, 1, 1))
    for i, axi in enumerate(ax.flat):
        axi.imshow(images[i])
        axi.set_axis_off()
    plt.suptitle(title, fontsize=24)
    plt.tight_layout(pad=0.2, rect=[0, 0, 1,0.9])
    plt.show()

# %%
 
plt.tight_layout(pad=0.2, rect=[0, 0, 1,0.9])
plt.show()
plot_images(covid_ct_images, 'Positive COVID-19 CT Scan')
plot_images(non_covid_ct_images, 'Negative COVID-19 CT Scan')

# %%
covid_ct_images = np.array(covid_ct_images) / 255
non_covid_ct_images = np.array(non_covid_ct_images) / 255

# %%
covid_ct_labels = np.array([1 for _ in range(len(covid_ct_images))])
non_covid_ct_labels = np.array([0 for _ in range(len(non_covid_ct_images))])

# %%
from sklearn.model_selection import train_test_split
covid_x_train, covid_x_test, covid_y_train, covid_y_test = train_test_split(covid_ct_images, covid_ct_labels, test_size=0.2)
noncovid_x_train, noncovid_x_test, noncovid_y_train, noncovid_y_test = train_test_split(non_covid_ct_images, non_covid_ct_labels, test_size=0.2)
X_train = np.concatenate((noncovid_x_train[:80], covid_x_train[:80]), axis=0)
X_test = np.concatenate((noncovid_x_test[80:], covid_x_test[80:]), axis=0)
y_train = np.concatenate((noncovid_y_train[:80], covid_y_train[:80]), axis=0)
y_test = np.concatenate((noncovid_y_test[80:], covid_y_test[80:]), axis=0)

# %%
print("Number of samples in train and test are %d and %d.",(X_train.shape[0],X_test.shape[0]))
# Out:
# Number of samples in train and test are %d and %d. (160, 345)

# %%
plot_images(covid_x_train, 'X_train')
plot_images(covid_x_test, 'X_test')

# %%
train_aug = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True
)

# %%
test_aug = ImageDataGenerator(rescale=1. /255)

# %%
model = tf.keras.models.Sequential([
  
    
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(224, 224, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
  
    
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
  
    
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
  
    
    tf.keras.layers.Conv2D(256, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
  
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'), 
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 222, 222, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 111, 111, 64)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 109, 109, 64)      36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 52, 52, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 26, 26, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 24, 24, 256)       295168
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 12, 12, 256)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 36864)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               18874880
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 19,283,137
# Trainable params: 19,283,137
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="binary_crossentropy",optimizer=RMSprop(lr=0.001),metrics=["accuracy"])

# %%
from keras import callbacks 
earlystopping = callbacks.EarlyStopping(monitor ="val_loss",  
                                        mode ="min", patience = 5,  
                                        restore_best_weights = True)

# %%
history = model.fit_generator(train_aug.flow(X_train, y_train, batch_size=batch_size),
                    validation_data=(X_test, y_test),
                    validation_steps=len(X_test) // batch_size,
                    steps_per_epoch=len(X_train) // batch_size,
                    epochs=epochs)
# Out:
# WARNING:tensorflow:From <ipython-input-24-d9bbccdd4bbc>:5: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/100
# 2/5 [===========>..................] - ETA: 0s - loss: 11.0744 - accuracy: 0.4531WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0528s vs `on_train_batch_end` time: 0.1050s). Check your callbacks.
# 5/5 [==============================] - 3s 635ms/step - loss: 5.4626 - accuracy: 0.4375 - val_loss: 0.6948 - val_accuracy: 0.4957
# Epoch 2/100
# 5/5 [==============================] - 2s 450ms/step - loss: 0.6980 - accuracy: 0.4625 - val_loss: 0.6951 - val_accuracy: 0.4957
# Epoch 3/100
# 5/5 [==============================] - 2s 450ms/step - loss: 0.6990 - accuracy: 0.4375 - val_loss: 0.6924 - val_accuracy: 0.4957
# Epoch 4/100
# 5/5 [==============================] - 2s 453ms/step - loss: 0.6897 - accuracy: 0.5813 - val_loss: 0.6908 - val_accuracy: 0.5072
# Epoch 5/100
# 5/5 [==============================] - 2s 452ms/step - loss: 0.6926 - accuracy: 0.5437 - val_loss: 0.7153 - val_accuracy: 0.4957
# Epoch 6/100
# 5/5 [==============================] - 2s 450ms/step - loss: 0.6901 - accuracy: 0.5000 - val_loss: 0.6883 - val_accuracy: 0.6203
# Epoch 7/100
# 5/5 [==============================] - 2s 452ms/step - loss: 0.8315 - accuracy: 0.5188 - val_loss: 0.7056 - val_accuracy: 0.4957
# Epoch 8/100
# 5/5 [==============================] - 2s 452ms/step - loss: 0.8055 - accuracy: 0.4750 - val_loss: 0.6922 - val_accuracy: 0.5304
# Epoch 9/100
# 5/5 [==============================] - 2s 452ms/step - loss: 0.6957 - accuracy: 0.5375 - val_loss: 0.6922 - val_accuracy: 0.5043
# Epoch 10/100
# 5/5 [==============================] - 2s 451ms/step - loss: 0.6933 - accuracy: 0.5063 - val_loss: 0.6895 - val_accuracy: 0.7188
# Epoch 11/100
# 5/5 [==============================] - 2s 447ms/step - loss: 0.6911 - accuracy: 0.5437 - val_loss: 0.7002 - val_accuracy: 0.4957
# Epoch 12/100
# 5/5 [==============================] - 2s 449ms/step - loss: 0.7122 - accuracy: 0.5625 - val_loss: 0.6991 - val_accuracy: 0.5043
# Epoch 13/100
# 5/5 [==============================] - 2s 448ms/step - loss: 0.6965 - accuracy: 0.5250 - val_loss: 0.6879 - val_accuracy: 0.4986
# Epoch 14/100
# 5/5 [==============================] - 2s 452ms/step - loss: 0.7025 - accuracy: 0.4625 - val_loss: 0.6901 - val_accuracy: 0.5043
# Epoch 15/100
# 5/5 [==============================] - 2s 445ms/step - loss: 0.6933 - accuracy: 0.4750 - val_loss: 0.7379 - val_accuracy: 0.5043
# Epoch 16/100
# 5/5 [==============================] - 2s 451ms/step - loss: 0.7032 - accuracy: 0.5000 - val_loss: 0.6860 - val_accuracy: 0.4957
# Epoch 17/100
# 5/5 [==============================] - 2s 448ms/step - loss: 0.6878 - accuracy: 0.5500 - val_loss: 0.6807 - val_accuracy: 0.6551
# Epoch 18/100
# 5/5 [==============================] - 2s 457ms/step - loss: 0.6951 - accuracy: 0.5437 - val_loss: 0.6885 - val_accuracy: 0.5043
# Epoch 19/100
# 5/5 [==============================] - 2s 452ms/step - loss: 0.7635 - accuracy: 0.4688 - val_loss: 0.6904 - val_accuracy: 0.5043
# Epoch 20/100
# 5/5 [==============================] - 2s 446ms/step - loss: 0.6953 - accuracy: 0.5125 - val_loss: 0.6847 - val_accuracy: 0.6870
# Epoch 21/100
# 5/5 [==============================] - 2s 449ms/step - loss: 0.6931 - accuracy: 0.5688 - val_loss: 0.6803 - val_accuracy: 0.6783
# Epoch 22/100
# 5/5 [==============================] - 2s 451ms/step - loss: 0.6818 - accuracy: 0.5813 - val_loss: 0.8754 - val_accuracy: 0.4957
# Epoch 23/100
# 5/5 [==============================] - 2s 446ms/step - loss: 0.6773 - accuracy: 0.5500 - val_loss: 0.6506 - val_accuracy: 0.6696
# Epoch 24/100
# 5/5 [==============================] - 2s 456ms/step - loss: 0.7241 - accuracy: 0.4875 - val_loss: 0.6866 - val_accuracy: 0.5826
# Epoch 25/100
# 5/5 [==============================] - 2s 453ms/step - loss: 0.6928 - accuracy: 0.4812 - val_loss: 0.6779 - val_accuracy: 0.6493
# Epoch 26/100
# 5/5 [==============================] - 2s 455ms/step - loss: 0.6825 - accuracy: 0.5437 - val_loss: 0.6708 - val_accuracy: 0.5420
# Epoch 27/100
# 5/5 [==============================] - 2s 452ms/step - loss: 0.6915 - accuracy: 0.4750 - val_loss: 0.6696 - val_accuracy: 0.5942
# Epoch 28/100
# 5/5 [==============================] - 2s 450ms/step - loss: 0.7123 - accuracy: 0.5188 - val_loss: 0.6757 - val_accuracy: 0.5188
# Epoch 29/100
# 5/5 [==============================] - 2s 451ms/step - loss: 0.7234 - accuracy: 0.5000 - val_loss: 0.6822 - val_accuracy: 0.5681
# Epoch 30/100
# 5/5 [==============================] - 2s 444ms/step - loss: 0.6972 - accuracy: 0.5312 - val_loss: 0.7104 - val_accuracy: 0.5043
# Epoch 31/100
# 5/5 [==============================] - 2s 450ms/step - loss: 0.6831 - accuracy: 0.6062 - val_loss: 0.6796 - val_accuracy: 0.5072
# Epoch 32/100
# 5/5 [==============================] - 2s 449ms/step - loss: 0.6724 - accuracy: 0.5688 - val_loss: 0.6375 - val_accuracy: 0.7304
# Epoch 33/100
# 5/5 [==============================] - 2s 446ms/step - loss: 0.7006 - accuracy: 0.5688 - val_loss: 0.6831 - val_accuracy: 0.5043
# Epoch 34/100
# 5/5 [==============================] - 2s 445ms/step - loss: 0.6770 - accuracy: 0.5250 - val_loss: 0.6649 - val_accuracy: 0.7101
# Epoch 35/100
# 5/5 [==============================] - 2s 448ms/step - loss: 0.6541 - accuracy: 0.6250 - val_loss: 0.6626 - val_accuracy: 0.5913
# Epoch 36/100
# 5/5 [==============================] - 2s 453ms/step - loss: 0.6693 - accuracy: 0.5688 - val_loss: 0.7311 - val_accuracy: 0.5420
# Epoch 37/100
# 5/5 [==============================] - 2s 445ms/step - loss: 0.6567 - accuracy: 0.6625 - val_loss: 0.6622 - val_accuracy: 0.5478
# Epoch 38/100
# 5/5 [==============================] - 2s 445ms/step - loss: 0.6893 - accuracy: 0.5437 - val_loss: 0.6431 - val_accuracy: 0.7217
# Epoch 39/100
# 5/5 [==============================] - 2s 447ms/step - loss: 0.6171 - accuracy: 0.6875 - val_loss: 3.5915 - val_accuracy: 0.4957
# Epoch 40/100
# 5/5 [==============================] - 2s 448ms/step - loss: 1.2281 - accuracy: 0.5437 - val_loss: 0.6275 - val_accuracy: 0.7333
# Epoch 41/100
# 5/5 [==============================] - 2s 447ms/step - loss: 0.6298 - accuracy: 0.7125 - val_loss: 0.6448 - val_accuracy: 0.5710
# Epoch 42/100
# 5/5 [==============================] - 2s 452ms/step - loss: 0.5932 - accuracy: 0.7188 - val_loss: 0.6520 - val_accuracy: 0.6029
# Epoch 43/100
# 5/5 [==============================] - 2s 450ms/step - loss: 0.6575 - accuracy: 0.5750 - val_loss: 0.5737 - val_accuracy: 0.7246
# Epoch 44/100
# 5/5 [==============================] - 2s 453ms/step - loss: 0.6018 - accuracy: 0.7125 - val_loss: 0.6104 - val_accuracy: 0.6783
# Epoch 45/100
# 5/5 [==============================] - 2s 454ms/step - loss: 0.6333 - accuracy: 0.6625 - val_loss: 0.6478 - val_accuracy: 0.6203
# Epoch 46/100
# 5/5 [==============================] - 2s 446ms/step - loss: 0.6181 - accuracy: 0.6500 - val_loss: 0.5719 - val_accuracy: 0.7159
# Epoch 47/100
# 5/5 [==============================] - 2s 449ms/step - loss: 0.5268 - accuracy: 0.7500 - val_loss: 0.8553 - val_accuracy: 0.5333
# Epoch 48/100
# 5/5 [==============================] - 2s 451ms/step - loss: 0.6684 - accuracy: 0.6562 - val_loss: 1.0361 - val_accuracy: 0.5014
# Epoch 49/100
# 5/5 [==============================] - 2s 451ms/step - loss: 0.6081 - accuracy: 0.6875 - val_loss: 0.6036 - val_accuracy: 0.6377
# Epoch 50/100
# 5/5 [==============================] - 2s 451ms/step - loss: 0.5368 - accuracy: 0.7500 - val_loss: 0.4981 - val_accuracy: 0.7565
# Epoch 51/100
# 5/5 [==============================] - 2s 449ms/step - loss: 0.6644 - accuracy: 0.6062 - val_loss: 0.6231 - val_accuracy: 0.6232
# Epoch 52/100
# 5/5 [==============================] - 2s 448ms/step - loss: 0.5535 - accuracy: 0.7250 - val_loss: 0.5630 - val_accuracy: 0.7478
# Epoch 53/100
# 5/5 [==============================] - 2s 448ms/step - loss: 0.5555 - accuracy: 0.7000 - val_loss: 0.6241 - val_accuracy: 0.6087
# Epoch 54/100
# 5/5 [==============================] - 2s 447ms/step - loss: 0.5386 - accuracy: 0.7063 - val_loss: 0.5145 - val_accuracy: 0.7391
# Epoch 55/100
# 5/5 [==============================] - 2s 450ms/step - loss: 0.5941 - accuracy: 0.7063 - val_loss: 0.5603 - val_accuracy: 0.7072
# Epoch 56/100
# 5/5 [==============================] - 2s 453ms/step - loss: 0.5633 - accuracy: 0.6938 - val_loss: 0.4789 - val_accuracy: 0.8145
# Epoch 57/100
# 5/5 [==============================] - 2s 450ms/step - loss: 0.4476 - accuracy: 0.8062 - val_loss: 0.5291 - val_accuracy: 0.7420
# Epoch 58/100
# 5/5 [==============================] - 2s 447ms/step - loss: 0.5869 - accuracy: 0.7250 - val_loss: 0.6431 - val_accuracy: 0.6841
# Epoch 59/100
# 5/5 [==============================] - 2s 450ms/step - loss: 0.4980 - accuracy: 0.7250 - val_loss: 0.4803 - val_accuracy: 0.7855
# Epoch 60/100
# 5/5 [==============================] - 2s 449ms/step - loss: 0.4231 - accuracy: 0.7750 - val_loss: 0.5645 - val_accuracy: 0.7072
# Epoch 61/100
# 5/5 [==============================] - 2s 456ms/step - loss: 0.6185 - accuracy: 0.6938 - val_loss: 0.8306 - val_accuracy: 0.6377
# Epoch 62/100
# 5/5 [==============================] - 2s 446ms/step - loss: 0.4879 - accuracy: 0.7625 - val_loss: 0.5135 - val_accuracy: 0.7681
# Epoch 63/100
# 5/5 [==============================] - 2s 459ms/step - loss: 0.6473 - accuracy: 0.6938 - val_loss: 0.6706 - val_accuracy: 0.6522
# Epoch 64/100
# 5/5 [==============================] - 2s 459ms/step - loss: 0.4819 - accuracy: 0.7812 - val_loss: 0.4690 - val_accuracy: 0.7797
# Epoch 65/100
# 5/5 [==============================] - 2s 448ms/step - loss: 0.4704 - accuracy: 0.8000 - val_loss: 0.5232 - val_accuracy: 0.7478
# Epoch 66/100
# 5/5 [==============================] - 2s 452ms/step - loss: 0.5020 - accuracy: 0.7063 - val_loss: 0.4323 - val_accuracy: 0.8145
# Epoch 67/100
# 5/5 [==============================] - 2s 450ms/step - loss: 0.3726 - accuracy: 0.8375 - val_loss: 0.7216 - val_accuracy: 0.7043
# Epoch 68/100
# 5/5 [==============================] - 2s 447ms/step - loss: 0.4056 - accuracy: 0.7937 - val_loss: 0.6653 - val_accuracy: 0.7072
# Epoch 69/100
# 5/5 [==============================] - 2s 446ms/step - loss: 0.5631 - accuracy: 0.7375 - val_loss: 0.4664 - val_accuracy: 0.7884
# Epoch 70/100
# 5/5 [==============================] - 2s 452ms/step - loss: 0.6533 - accuracy: 0.6812 - val_loss: 0.6505 - val_accuracy: 0.6493
# Epoch 71/100
# 5/5 [==============================] - 2s 454ms/step - loss: 0.4561 - accuracy: 0.7875 - val_loss: 0.4657 - val_accuracy: 0.7855
# Epoch 72/100
# 5/5 [==============================] - 2s 452ms/step - loss: 0.5228 - accuracy: 0.7375 - val_loss: 0.5001 - val_accuracy: 0.7681
# Epoch 73/100
# 5/5 [==============================] - 2s 447ms/step - loss: 0.4910 - accuracy: 0.7375 - val_loss: 0.4386 - val_accuracy: 0.8145
# Epoch 74/100
# 5/5 [==============================] - 2s 452ms/step - loss: 0.4365 - accuracy: 0.7688 - val_loss: 0.5868 - val_accuracy: 0.7710
# Epoch 75/100
# 5/5 [==============================] - 2s 448ms/step - loss: 0.4426 - accuracy: 0.8188 - val_loss: 0.4433 - val_accuracy: 0.8145
# Epoch 76/100
# 5/5 [==============================] - 2s 451ms/step - loss: 0.3610 - accuracy: 0.8625 - val_loss: 0.4771 - val_accuracy: 0.7797
# Epoch 77/100
# 5/5 [==============================] - 2s 453ms/step - loss: 0.5258 - accuracy: 0.7625 - val_loss: 0.5183 - val_accuracy: 0.7710
# Epoch 78/100
# 5/5 [==============================] - 2s 452ms/step - loss: 0.3854 - accuracy: 0.8562 - val_loss: 0.4461 - val_accuracy: 0.8029
# Epoch 79/100
# 5/5 [==============================] - 2s 445ms/step - loss: 0.4704 - accuracy: 0.8125 - val_loss: 0.4131 - val_accuracy: 0.8319
# Epoch 80/100
# 5/5 [==============================] - 2s 450ms/step - loss: 0.4901 - accuracy: 0.7750 - val_loss: 0.4533 - val_accuracy: 0.7971
# Epoch 81/100
# 5/5 [==============================] - 2s 451ms/step - loss: 0.5049 - accuracy: 0.8000 - val_loss: 0.4699 - val_accuracy: 0.8029
# Epoch 82/100
# 5/5 [==============================] - 2s 453ms/step - loss: 0.4075 - accuracy: 0.8250 - val_loss: 0.4072 - val_accuracy: 0.8377
# Epoch 83/100
# 5/5 [==============================] - 2s 449ms/step - loss: 0.4703 - accuracy: 0.8000 - val_loss: 0.4673 - val_accuracy: 0.7884
# Epoch 84/100
# 5/5 [==============================] - 2s 453ms/step - loss: 0.5201 - accuracy: 0.7875 - val_loss: 0.5957 - val_accuracy: 0.7014
# Epoch 85/100
# 5/5 [==============================] - 2s 452ms/step - loss: 0.4202 - accuracy: 0.8313 - val_loss: 0.4398 - val_accuracy: 0.8116
# Epoch 86/100
# 5/5 [==============================] - 2s 451ms/step - loss: 0.4014 - accuracy: 0.8313 - val_loss: 0.4294 - val_accuracy: 0.8058
# Epoch 87/100
# 5/5 [==============================] - 2s 449ms/step - loss: 0.4195 - accuracy: 0.8375 - val_loss: 0.5357 - val_accuracy: 0.7681
# Epoch 88/100
# 5/5 [==============================] - 2s 449ms/step - loss: 0.4503 - accuracy: 0.7875 - val_loss: 0.4000 - val_accuracy: 0.8174
# Epoch 89/100
# 5/5 [==============================] - 2s 446ms/step - loss: 0.4015 - accuracy: 0.8250 - val_loss: 0.4133 - val_accuracy: 0.8087
# Epoch 90/100
# 5/5 [==============================] - 2s 451ms/step - loss: 0.3845 - accuracy: 0.8000 - val_loss: 0.6453 - val_accuracy: 0.7188
# Epoch 91/100
# 5/5 [==============================] - 2s 448ms/step - loss: 0.4543 - accuracy: 0.7937 - val_loss: 0.4787 - val_accuracy: 0.7623
# Epoch 92/100
# 5/5 [==============================] - 2s 450ms/step - loss: 0.3919 - accuracy: 0.8625 - val_loss: 0.5276 - val_accuracy: 0.7391
# Epoch 93/100
# 5/5 [==============================] - 2s 456ms/step - loss: 0.4541 - accuracy: 0.7688 - val_loss: 0.4181 - val_accuracy: 0.8232
# Epoch 94/100
# 5/5 [==============================] - 2s 454ms/step - loss: 0.3967 - accuracy: 0.8125 - val_loss: 0.6326 - val_accuracy: 0.7043
# Epoch 95/100
# 5/5 [==============================] - 2s 453ms/step - loss: 0.3832 - accuracy: 0.8125 - val_loss: 0.5211 - val_accuracy: 0.7739
# Epoch 96/100
# 5/5 [==============================] - 2s 454ms/step - loss: 0.5108 - accuracy: 0.7125 - val_loss: 0.4444 - val_accuracy: 0.7971
# Epoch 97/100
# 5/5 [==============================] - 2s 450ms/step - loss: 0.3723 - accuracy: 0.8500 - val_loss: 0.4597 - val_accuracy: 0.8029
# Epoch 98/100
# 5/5 [==============================] - 2s 448ms/step - loss: 0.4763 - accuracy: 0.7625 - val_loss: 0.4229 - val_accuracy: 0.8319
# Epoch 99/100
# 5/5 [==============================] - 2s 443ms/step - loss: 0.3522 - accuracy: 0.8500 - val_loss: 0.4330 - val_accuracy: 0.8203
# Epoch 100/100
# 5/5 [==============================] - 2s 445ms/step - loss: 0.2777 - accuracy: 0.8750 - val_loss: 0.3546 - val_accuracy: 0.8667

# %%
score = model.evaluate(X_test, y_test, verbose = 0) 
print('Test loss:', score[0]) 
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.35460206866264343
# Test accuracy: 0.8666666746139526

# %%
y_pred = model.predict(X_test, batch_size=batch_size)
prediction=y_pred[1:10]
for index, probability in enumerate(prediction):
  if probability[0] > 0.5:
     plt.title('%.2f' % (probability[0]*100) + '% COVID_CT')
  else:
    plt.title('%.2f' % ((1-probability[0])*100) + '% NONCOVID_CT')
  plt.imshow(X_test[index])
  plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])
plt.show()
